# %%
df = spark.read.json("/Workspace/Users/Databricks-Course/product.json")
display(df)

# %%
df.printSchema()

# %%
from pyspark.sql.types import StringType, BooleanType, LongType, DoubleType, StructField, StructType
schema = StructType({
    StructField("brand", StringType()),
    StructField("category", StringType()),
    StructField("ingestion_timestamp", StringType()),
    StructField("is_active", BooleanType()),
    StructField("name", StringType()),
    StructField("price", DoubleType()),
    StructField("product_id", LongType()),
    StructField("rating", DoubleType()),
    StructField("stock_quantity", LongType())
})
df1 = spark.read.json("/Workspace/Users/Databricks-Course/product.json", schema=schema)
